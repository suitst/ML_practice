# %%
# import packages and data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import joblib
import warnings
warnings.filterwarnings('ignore')

tr_features = pd.read_csv('./x_train_features.csv')
tr_labels = pd.read_csv('./y_train_labels.csv')

# %%
def print_results(results):
    print(f'Best Params: {results.best_params_}')
    
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    
    print('Test results:')
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean, 3)} (+/-{round(std, 3)}) for {params}')
        
        
def pkl_best_params(results, model_type: str):
    joblib.dump(results.best_estimator_, f'./{model_type}_model.pkl')
    
    
def plot_performance(results):
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    best_est = results.best_estimator_
    columns = list(results.cv_results_)
    rows = [f'{x}' for x in results.cv_results_['params']]
    nrows = len(results.cv_results_)      
    
    
    plt.figure(figsize=(16,9))
    plt.bar(rows, means)
    plt.xticks(rotation=45, ha="right")
    
    plt.show()

# %%
lr = LogisticRegression(max_iter=500)
params = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}

lr_cv = GridSearchCV(lr, params, cv=5) # creates the cross-validation object
lr_cv.fit(tr_features, tr_labels.values.ravel()) # .ravel() converts tr_labels from an object vector to an array

print_results(lr_cv)
# Out:
# Best Params: {'C': 0.1}
# Test results:
# 0.524 (+/-0.006) for {'C': 0.001}
# 0.701 (+/-0.043) for {'C': 0.01}
# 0.799 (+/-0.059) for {'C': 0.1}
# 0.789 (+/-0.051) for {'C': 1}
# 0.775 (+/-0.039) for {'C': 10}
# 0.772 (+/-0.039) for {'C': 100}
# 0.772 (+/-0.039) for {'C': 1000}

# %%
plot_performance(lr_cv)

# %%
# save best params as pkl

pkl_best_params(lr_cv, 'LR')

# %%
# create support vector machine model

svc = SVC()
svc_params = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [0.1, 1, 10]
}

svc_cv = GridSearchCV(svc, svc_params, cv=5)
svc_cv.fit(tr_features, tr_labels.values.ravel())

print_results(svc_cv)
# Out:
# Best Params: {'C': 0.1, 'kernel': 'linear'}
# Test results:
# 0.796 (+/-0.068) for {'C': 0.1, 'kernel': 'linear'}
# 0.789 (+/-0.042) for {'C': 0.1, 'kernel': 'poly'}
# 0.776 (+/-0.048) for {'C': 0.1, 'kernel': 'rbf'}
# 0.638 (+/-0.032) for {'C': 0.1, 'kernel': 'sigmoid'}
# 0.789 (+/-0.053) for {'C': 1, 'kernel': 'linear'}
# 0.762 (+/-0.022) for {'C': 1, 'kernel': 'poly'}
# 0.772 (+/-0.047) for {'C': 1, 'kernel': 'rbf'}
# 0.607 (+/-0.065) for {'C': 1, 'kernel': 'sigmoid'}
# 0.786 (+/-0.044) for {'C': 10, 'kernel': 'linear'}
# 0.762 (+/-0.048) for {'C': 10, 'kernel': 'poly'}
# 0.779 (+/-0.051) for {'C': 10, 'kernel': 'rbf'}
# 0.577 (+/-0.061) for {'C': 10, 'kernel': 'sigmoid'}

# %%
plot_performance(svc_cv)

# %%
# save best params as pkl

pkl_best_params(svc_cv, 'SVM')

# %%
# create multi-layer perceptron model

mlp = MLPClassifier()
mlp_params = {
    'hidden_layer_sizes':[(10,), (10,2), (50,), (100,), (500,)],
    'activation': ['relu', 'tanh', 'logistic'],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

mlp_cv = GridSearchCV(mlp, mlp_params, cv=5)
mlp_cv.fit(tr_features, tr_labels.values.ravel())

print_results(mlp_cv)
# Out:
# Best Params: {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# Test results:
# 0.786 (+/-0.067) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.779 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.762 (+/-0.037) for {'activation': 'relu', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.726 (+/-0.138) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.789 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.726 (+/-0.111) for {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.762 (+/-0.06) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.769 (+/-0.054) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.769 (+/-0.058) for {'activation': 'relu', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.776 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.776 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.772 (+/-0.059) for {'activation': 'relu', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.755 (+/-0.057) for {'activation': 'relu', 'hidden_layer_sizes': (500,), 'learning_rate': 'constant'}
# 0.775 (+/-0.043) for {'activation': 'relu', 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling'}
# 0.765 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive'}
# 0.776 (+/-0.08) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.779 (+/-0.069) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.745 (+/-0.062) for {'activation': 'tanh', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.799 (+/-0.063) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.779 (+/-0.054) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.789 (+/-0.064) for {'activation': 'tanh', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.772 (+/-0.062) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.789 (+/-0.053) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.772 (+/-0.052) for {'activation': 'tanh', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.772 (+/-0.054) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.772 (+/-0.046) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.775 (+/-0.048) for {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.765 (+/-0.05) for {'activation': 'tanh', 'hidden_layer_sizes': (500,), 'learning_rate': 'constant'}
# 0.762 (+/-0.05) for {'activation': 'tanh', 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling'}
# 0.779 (+/-0.036) for {'activation': 'tanh', 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive'}
# 0.755 (+/-0.049) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'constant'}
# 0.769 (+/-0.056) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling'}
# 0.752 (+/-0.05) for {'activation': 'logistic', 'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive'}
# 0.642 (+/-0.101) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'constant'}
# 0.537 (+/-0.069) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'invscaling'}
# 0.554 (+/-0.057) for {'activation': 'logistic', 'hidden_layer_sizes': (10, 2), 'learning_rate': 'adaptive'}
# 0.782 (+/-0.069) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'constant'}
# 0.779 (+/-0.072) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'invscaling'}
# 0.776 (+/-0.072) for {'activation': 'logistic', 'hidden_layer_sizes': (50,), 'learning_rate': 'adaptive'}
# 0.769 (+/-0.053) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'constant'}
# 0.779 (+/-0.068) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'invscaling'}
# 0.769 (+/-0.06) for {'activation': 'logistic', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive'}
# 0.765 (+/-0.048) for {'activation': 'logistic', 'hidden_layer_sizes': (500,), 'learning_rate': 'constant'}
# 0.769 (+/-0.048) for {'activation': 'logistic', 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling'}
# 0.776 (+/-0.069) for {'activation': 'logistic', 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive'}

# %%
# save best params as pkl

pkl_best_params(mlp_cv, 'MLP')

# %%
plot_performance(mlp_cv)

# %%
# create random forest model

rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [5, 50, 250],
    'max_depth': [2, 4, 8, 16, 32, None]
}

rf_cv = GridSearchCV(rf, rf_params, cv=5)
rf_cv.fit(tr_features, tr_labels.values.ravel())

print_results(rf_cv)
# Out:
# Best Params: {'max_depth': 4, 'n_estimators': 250}
# Test results:
# 0.715 (+/-0.069) for {'max_depth': 2, 'n_estimators': 5}
# 0.752 (+/-0.08) for {'max_depth': 2, 'n_estimators': 50}
# 0.759 (+/-0.046) for {'max_depth': 2, 'n_estimators': 250}
# 0.745 (+/-0.048) for {'max_depth': 4, 'n_estimators': 5}
# 0.775 (+/-0.057) for {'max_depth': 4, 'n_estimators': 50}
# 0.786 (+/-0.065) for {'max_depth': 4, 'n_estimators': 250}
# 0.768 (+/-0.045) for {'max_depth': 8, 'n_estimators': 5}
# 0.755 (+/-0.072) for {'max_depth': 8, 'n_estimators': 50}
# 0.769 (+/-0.073) for {'max_depth': 8, 'n_estimators': 250}
# 0.739 (+/-0.06) for {'max_depth': 16, 'n_estimators': 5}
# 0.762 (+/-0.067) for {'max_depth': 16, 'n_estimators': 50}
# 0.769 (+/-0.066) for {'max_depth': 16, 'n_estimators': 250}
# 0.756 (+/-0.075) for {'max_depth': 32, 'n_estimators': 5}
# 0.735 (+/-0.073) for {'max_depth': 32, 'n_estimators': 50}
# 0.772 (+/-0.075) for {'max_depth': 32, 'n_estimators': 250}
# 0.745 (+/-0.043) for {'max_depth': None, 'n_estimators': 5}
# 0.752 (+/-0.08) for {'max_depth': None, 'n_estimators': 50}
# 0.762 (+/-0.067) for {'max_depth': None, 'n_estimators': 250}

# %%
plot_performance(rf_cv)

# %%
# save best params as pkl

pkl_best_params(rf_cv, 'RF')

# %%
# create gradient boosting model

gbm = GradientBoostingClassifier()
gbm_params = {
    'n_estimators': [5, 50, 250, 500],
    'max_depth': [1, 2, 3, 5, 8],
    'learning_rate': [0.01, 0.1, 1, 10, 100]
}

gbm_cv = GridSearchCV(gbm, gbm_params, cv=5)
gbm_cv.fit(tr_features, tr_labels.values.ravel())

print_results(gbm_cv)
# Out:
# Best Params: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# Test results:
# 0.524 (+/-0.006) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5}
# 0.762 (+/-0.036) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50}
# 0.755 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 250}
# 0.772 (+/-0.035) for {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500}
# 0.524 (+/-0.006) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 5}
# 0.755 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50}
# 0.755 (+/-0.039) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 250}
# 0.775 (+/-0.058) for {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500}
# 0.567 (+/-0.055) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5}
# 0.749 (+/-0.074) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# 0.759 (+/-0.091) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 250}
# 0.752 (+/-0.09) for {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.604 (+/-0.051) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5}
# 0.728 (+/-0.054) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}
# 0.735 (+/-0.052) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 250}
# 0.749 (+/-0.088) for {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# 0.668 (+/-0.035) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 5}
# 0.681 (+/-0.049) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
# 0.695 (+/-0.047) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 250}
# 0.698 (+/-0.077) for {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 500}
# 0.769 (+/-0.037) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5}
# 0.772 (+/-0.035) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50}
# 0.782 (+/-0.063) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 250}
# 0.765 (+/-0.071) for {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500}
# 0.755 (+/-0.039) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 5}
# 0.775 (+/-0.05) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.732 (+/-0.108) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 250}
# 0.732 (+/-0.1) for {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500}
# 0.749 (+/-0.09) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5}
# 0.749 (+/-0.076) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# 0.742 (+/-0.118) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 250}
# 0.732 (+/-0.117) for {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# 0.732 (+/-0.045) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5}
# 0.756 (+/-0.098) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# 0.732 (+/-0.12) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 250}
# 0.749 (+/-0.096) for {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500}
# 0.698 (+/-0.052) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 5}
# 0.715 (+/-0.058) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 50}
# 0.702 (+/-0.111) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 250}
# 0.732 (+/-0.066) for {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 500}
# 0.752 (+/-0.04) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 5}
# 0.739 (+/-0.073) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.705 (+/-0.092) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 250}
# 0.702 (+/-0.103) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 500}
# 0.779 (+/-0.056) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 5}
# 0.715 (+/-0.046) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50}
# 0.702 (+/-0.097) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 250}
# 0.715 (+/-0.096) for {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 500}
# 0.742 (+/-0.053) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 5}
# 0.722 (+/-0.094) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.729 (+/-0.106) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 250}
# 0.729 (+/-0.106) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 500}
# 0.728 (+/-0.06) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 5}
# 0.735 (+/-0.082) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.735 (+/-0.097) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 250}
# 0.752 (+/-0.104) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 500}
# 0.715 (+/-0.069) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 5}
# 0.705 (+/-0.09) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 50}
# 0.732 (+/-0.07) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 250}
# 0.718 (+/-0.071) for {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 500}
# 0.231 (+/-0.05) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 5}
# 0.231 (+/-0.05) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 50}
# 0.231 (+/-0.05) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 250}
# 0.231 (+/-0.05) for {'learning_rate': 10, 'max_depth': 1, 'n_estimators': 500}
# 0.452 (+/-0.225) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 5}
# 0.452 (+/-0.225) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 50}
# 0.452 (+/-0.225) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 250}
# 0.452 (+/-0.225) for {'learning_rate': 10, 'max_depth': 2, 'n_estimators': 500}
# 0.547 (+/-0.12) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 5}
# 0.497 (+/-0.103) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 50}
# 0.511 (+/-0.081) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 250}
# 0.439 (+/-0.141) for {'learning_rate': 10, 'max_depth': 3, 'n_estimators': 500}
# 0.591 (+/-0.133) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 5}
# 0.594 (+/-0.128) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 50}
# 0.574 (+/-0.124) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 250}
# 0.594 (+/-0.138) for {'learning_rate': 10, 'max_depth': 5, 'n_estimators': 500}
# 0.698 (+/-0.062) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 5}
# 0.722 (+/-0.054) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 50}
# 0.698 (+/-0.069) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 250}
# 0.705 (+/-0.075) for {'learning_rate': 10, 'max_depth': 8, 'n_estimators': 500}
# 0.476 (+/-0.006) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 5}
# 0.476 (+/-0.006) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 50}
# 0.476 (+/-0.006) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 250}
# 0.476 (+/-0.006) for {'learning_rate': 100, 'max_depth': 1, 'n_estimators': 500}
# 0.443 (+/-0.042) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 5}
# 0.443 (+/-0.042) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 50}
# 0.443 (+/-0.042) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 250}
# 0.443 (+/-0.042) for {'learning_rate': 100, 'max_depth': 2, 'n_estimators': 500}
# 0.47 (+/-0.04) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 5}
# 0.47 (+/-0.04) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 50}
# 0.496 (+/-0.146) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 250}
# 0.443 (+/-0.056) for {'learning_rate': 100, 'max_depth': 3, 'n_estimators': 500}
# 0.51 (+/-0.06) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 5}
# 0.524 (+/-0.045) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 50}
# 0.53 (+/-0.046) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 250}
# 0.517 (+/-0.06) for {'learning_rate': 100, 'max_depth': 5, 'n_estimators': 500}
# 0.708 (+/-0.039) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 5}
# 0.712 (+/-0.068) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 50}
# 0.735 (+/-0.045) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 250}
# 0.725 (+/-0.059) for {'learning_rate': 100, 'max_depth': 8, 'n_estimators': 500}

# %%
plot_performance(gbm_cv)

# %%
# save best params as pkl

pkl_best_params(gbm_cv, 'GBM')
